# %%
pip install pandas
# Out:
# ...
#
# ...

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_excel("C:/Users/hp/Downloads/ESD.xlsx")

# %%
print(pd.DataFrame(df))
# Out:
#        EEID        Full Name                 Job Title  Department  \
# 0    E02387      Emily Davis                Sr. Manger          IT
# 1    E04105    Theodore Dinh       Technical Architect          IT
# 2    E02572     Luna Sanders                  Director     Finance
# 3    E02832  Penelope Jordan  Computer Systems Manager          IT
# 4    E01639        Austin Vo               Sr. Analyst     Finance
# ..      ...              ...                       ...         ...
# 995  E03094     Wesley Young               Sr. Analyst   Marketing
# 996  E01909     Lillian Khan                   Analyst     Finance
# 997  E04398      Oliver Yang                  Director   Marketing
# 998  E02521      Lily Nguyen               Sr. Analyst     Finance
# 999  E03545      Sofia Cheng            Vice President  Accounting
#
#               Business Unit  Gender  Ethnicity  Age  Hire Date  Annual Salary  \
# 0    Research & Development  Female      Black   55 2016-04-08         141604
# ...

# %%
df.describe()
# Out:
#                Age                   Hire Date  Annual Salary      Bonus %  \
# count  1000.000000                        1000    1000.000000  1000.000000
# mean     44.382000  2012-04-07 02:54:14.400000  113217.365000     0.088660
# min      25.000000         1992-01-09 00:00:00   40063.000000     0.000000
# 25%      35.000000         2007-02-14 00:00:00   71430.250000     0.000000
# 50%      45.000000         2014-02-15 12:00:00   96557.000000     0.000000
# 75%      54.000000         2018-06-22 00:00:00  150782.250000     0.150000
# max      65.000000         2021-12-26 00:00:00  258498.000000     0.400000
# std      11.246981                         NaN   53545.985644     0.117856
#
#                            Exit Date
# count                             85
# mean   2016-11-02 18:04:14.117647104
# min              1994-12-18 00:00:00
# 25%              2014-12-25 00:00:00
# 50%              2019-05-23 00:00:00
# 75%              2021-04-09 00:00:00
# ...

# %%
df.shape
# Out:
# (1000, 14)

# %%
group1 = df.groupby(["Job Title","Full Name"]).agg({"Annual Salary":["mean", "sum"],"Age":["mean","max"]})

# %%
print(group1)
# Out:
#                               Annual Salary           Age
#                                        mean     sum  mean max
# Job Title              EEID
# Account Representative E00022       64669.0   64669  62.0  62
#                        E00644       50994.0   50994  57.0  57
#                        E00725       65047.0   65047  45.0  45
#                        E00749       64204.0   64204  37.0  37
#                        E00758       59646.0   59646  35.0  35
# ...                                     ...     ...   ...  ..
# Vice President         E04766      191571.0  191571  38.0  38
#                        E04779      180994.0  180994  63.0  63
#                        E04795      208210.0  208210  28.0  28
#                        E04940      195200.0  195200  36.0  36
#                        E04962      181801.0  181801  50.0  50
#
# [997 rows x 4 columns]

# %%
group1 = df.groupby("Job Title").agg({"Annual Salary":["mean","min"],"Ethnicity":["count","min"]})

# %%
print(group1)
# Out:
#                                 Annual Salary         Ethnicity
#                                          mean     min     count    min
# Job Title
# Account Representative           62281.619048   50994        21  Asian
# Analyst                          49950.666667   40752        51  Asian
# Analyst II                       62647.471698   50685        53  Asian
# Automation Engineer              95106.857143   78237         7  Asian
# Business Partner                 49559.789474   41728        19  Asian
# Cloud Infrastructure Architect   86961.333333   62335        15  Asian
# Computer Systems Manager         80346.809524   61886        21  Asian
# Controls Engineer                99626.133333   76272        15  Asian
# Development Engineer             77889.210526   60132        19  Asian
# Director                        171633.851240  150399       121  Asian
# Engineering Manager             101853.800000   78938        20  Asian
# ...

# %%
group1 = df.groupby("Business Unit").agg({"Annual Salary":["mean","median","max"]})

# %%
print(group1)
# Out:
#                         Annual Salary
#                                  mean    median     max
# Business Unit
# Corporate               120776.151899  101143.0  258426
# Manufacturing           103651.371747   90040.0  258498
# Research & Development  112490.205240   96567.0  256561
# Speciality Products     116796.003774  101985.0  255230

# %%
#count people by deparments
group1 = df.groupby("Department")["EEID"].count()

# %%
print(group1)
# Out:
# Department
# Accounting          96
# Engineering        158
# Finance            120
# Human Resources    125
# IT                 241
# Marketing          120
# Sales              140
# Name: EEID, dtype: int64

# %%
#total salary
group1 = df["Annual Salary"].sum()

# %%
print(group1)
# Out:
# 113217365

# %%
#gender percentage
group1 = (df["Gender"].value_counts(normalize=True)*100)

# %%
print(group1)
# Out:
# Gender
# Female    51.8
# Male      48.2
# Name: proportion, dtype: float64

# %%
#department percentage
group1 = (df["Department"].value_count
